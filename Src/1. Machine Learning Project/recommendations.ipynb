# %% [markdown]
# **6. Exploring book rating data**

# %%
liked_books = ["17788401", "44676678", "36411676", "62058385", "62056935", "58583724", "62057697", "60156155", 
               "62022434", "32620332", "23546634", "60393672", "58346977", "27362503", "25912358"]
#Defines a list called liked_books that contains book IDs.

# %% [markdown]
# **Find all the users that like the same books as us then find all the books that they liked (Assumption: They have similar taste).**

# %%
# !head book_id_map.csv
# Out:
# 500 Can't connect to book_id_map.csv:80 (Bad hostname 'book_id_map.csv')
# Content-Type: text/plain
# Client-Date: Tue, 09 May 2023 01:47:02 GMT
# Client-Warning: Internal response

# %%
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
csv_book_mapping['0']
# Out:
# '34684622'

# %%
# !wc -l goodreads_interactions.csv
#Uses the wc -l command to count the number of lines in the "goodreads_interactions.csv" file.
# Out:
#  228648343 goodreads_interactions.csv

# %% [markdown]
# **Size of goodreads_interactions.csv**

# %%
# !ls -lh | grep goodreads_interactions.csv
#Uses the ls -lh command to display the size of the "goodreads_interactions.csv" file.
# Out:
# -rw-r--r--@ 1 britneyagius  staff   4.0G Mar  8 13:47 goodreads_interactions.csv

# %% [markdown]
# **7. Finding users who like the same books as us**

# %% [markdown]
# **A set is a python data structure where every element is unique.**

# %% [markdown]
# **if user_id in overlap_users: continue - means that if we already added this user to our overlap user set we don't need to keep processing.**

# %%
#data = pd.read_csv("goodreads_interactions.csv")
#data.head(n=9)

# %%
overlap_users = set()

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        book_id = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)
        
#Reads the "goodreads_interactions.csv" file and finds users who have rated the same books as in liked_books with a rating of 4 or higher

# %% [markdown]
# **8. Finding what books those users liked**

# %% [markdown]
# **rec_lines will only contin books that users who likes the same books as us have read.**

# %% [markdown]
# **rec_lines will contain books we might want to read.**

# %%
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

#Reads the "goodreads_interactions.csv" file again and extracts the books that the overlapping users have rated highly.

# %%
import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#          user_id   book_id rating
# 0             14  12881778      5
# 1             14  10818853      5
# 2             14  11857408      5
# 3             14  18806659      5
# 4             14  13448656      5
# ...          ...       ...    ...
# 15082684  875876   8520610      0
# 15082685  875876      9013      0
# 15082686  875876  29751398      0
# 15082687  875876  29780253      5
# 15082688  875876  30231812      0
#
# [15082689 rows x 3 columns]

# %% [markdown]
# **top_recs = recs("book_id").value_counts() - It counts up how many times each book id occured and it shows you the most common ones so our top recommendations will be our book ids that occured the most frequently.**

# %%
top_recs = recs["book_id"].value_counts().head(10)

# %% [markdown]
# **To get from the book id to a title: Read in from the file books_titles.json**

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140  \
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url
# 0  https://www.goodreads.com/book/show/7327624-th...  \
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image
# 0  https://images.gr-assets.com/books/1304100136m...  \
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %% [markdown]
# **9. Creating initial book recommendations**

# %% [markdown]
# **Finds all of the book titles where the book id is in the top recommendations.**

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
# Empty DataFrame
# Columns: [book_id, title, ratings, url, cover_image, mod_title]
# Index: []

# %% [markdown]
# **10. Improving our book recommendations**

# %%
all_recs = recs["book_id"].value_counts()
#Converts rec_lines into a DataFrame called recs.

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs.head(5)
# Out:
#     book_id  book_count
# 0  17788401       15131
# 1  27362503       13202
# 2  11870085       13003
# 3   2767052       12785
# 4     41865       12417

# %% [markdown]
# **Inner merge means that if the data dosen't exist in both get rid of the row.**

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %% [markdown]
# **A score will be created which we be used to sort these recommendations.**

# %%
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#        book_id  book_count                                       title
# 3663  31681941         610                            The Comfort Zone  \
# 2310  24909347         889           Obsidio (The Illuminae Files, #3)
# 5772  32333338         415                               Save the Date
# 2837  29749098         748        Catwoman: Soulstealer (DC Icons, #3)
# 4365  34705684         527            Cracked Kingdom (The Royals, #5)
# 3736  23865291         599        All Closed Off (Rusk University, #4)
# 3980  26181560         566                           Forget You, Ethan
# 7791  27212267         309       Darkness Embraced (Hades Hangmen, #7)
# 7198  27212250         334            Crux Untamed (Hades Hangmen, #6)
# 1503  31050237        1238  Untitled (A Court of Thorns and Roses, #4)
#
#       ratings                                                url
# 3663       36  https://www.goodreads.com/book/show/31681941-t...  \
# 2310       82  https://www.goodreads.com/book/show/24909347-o...
# 5772       19  https://www.goodreads.com/book/show/32333338-s...
# 2837       73  https://www.goodreads.com/book/show/29749098-c...
# 4365       39  https://www.goodreads.com/book/show/34705684-c...
# 3736       54  https://www.goodreads.com/book/show/23865291-a...
# 3980       49  https://www.goodreads.com/book/show/26181560-f...
# 7791       16  https://www.goodreads.com/book/show/27212267-d...
# 7198       19  https://www.goodreads.com/book/show/27212250-c...
# 1503      264  https://www.goodreads.com/book/show/31050237-u...
#
#                                             cover_image
# 3663  https://s.gr-assets.com/assets/nophoto/book/11...  \
# 2310  https://images.gr-assets.com/books/1501704611m...
# 5772  https://images.gr-assets.com/books/1510611507m...
# 2837  https://s.gr-assets.com/assets/nophoto/book/11...
# 4365  https://s.gr-assets.com/assets/nophoto/book/11...
# 3736  https://images.gr-assets.com/books/1490797036m...
# 3980  https://images.gr-assets.com/books/1504787872m...
# 7791  https://s.gr-assets.com/assets/nophoto/book/11...
# 7198  https://s.gr-assets.com/assets/nophoto/book/11...
# 1503  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                    mod_title         score
# 3663                        the comfort zone  10336.111111
# 2310           obsidio the illuminae files 3   9638.060976
# 5772                           save the date   9064.473684
# 2837         catwoman soulstealer dc icons 3   7664.438356
# 4365            cracked kingdom the royals 5   7121.256410
# 3736        all closed off rusk university 4   6644.462963
# 3980                        forget you ethan   6537.877551
# 7791       darkness embraced hades hangmen 7   5967.562500
# 7198            crux untamed hades hangmen 6   5871.368421
# 1503  untitled a court of thorns and roses 4   5805.469697

# %%
all_recs[all_recs["book_count"] > 700].sort_values("score", ascending=False).head(10)
# Out:
#        book_id  book_count                                              title
# 2310  24909347         889                  Obsidio (The Illuminae Files, #3)  \
# 2837  29749098         748               Catwoman: Soulstealer (DC Icons, #3)
# 1503  31050237        1238         Untitled (A Court of Thorns and Roses, #4)
# 2288  31050358         896         Untitled (A Court of Thorns and Roses, #5)
# 2680  30809786         787  A Reaper at the Gates (An Ember in the Ashes, #3)
# 638   33590260        2139                     Untitled (Throne of Glass, #7)
# 2576  17699859         816               Chain of Thorns (The Last Hours, #3)
# 2883  15776693         740                                            Options
# 1989  17699853         996                 Chain of Gold (The Last Hours, #1)
# 1415  13541056        1291  The Queen of Air and Darkness (The Dark Artifi...
#
#       ratings                                                url
# 2310       82  https://www.goodreads.com/book/show/24909347-o...  \
# 2837       73  https://www.goodreads.com/book/show/29749098-c...
# 1503      264  https://www.goodreads.com/book/show/31050237-u...
# 2288      146  https://www.goodreads.com/book/show/31050358-u...
# 2680      124  https://www.goodreads.com/book/show/30809786-a...
# 638      1190  https://www.goodreads.com/book/show/33590260-u...
# 2576      185  https://www.goodreads.com/book/show/17699859-c...
# 2883      154  https://www.goodreads.com/book/show/15776693-o...
# 1989      287  https://www.goodreads.com/book/show/17699853-c...
# 1415      516  https://www.goodreads.com/book/show/13541056-q...
#
#                                             cover_image
# 2310  https://images.gr-assets.com/books/1501704611m...  \
# 2837  https://s.gr-assets.com/assets/nophoto/book/11...
# 1503  https://s.gr-assets.com/assets/nophoto/book/11...
# 2288  https://s.gr-assets.com/assets/nophoto/book/11...
# 2680  https://images.gr-assets.com/books/1507476834m...
# 638   https://images.gr-assets.com/books/1488914165m...
# 2576  https://s.gr-assets.com/assets/nophoto/book/11...
# 2883  https://images.gr-assets.com/books/1345320956m...
# 1989  https://s.gr-assets.com/assets/nophoto/book/11...
# 1415  https://images.gr-assets.com/books/1510447136m...
#
#                                               mod_title        score
# 2310                      obsidio the illuminae files 3  9638.060976
# 2837                    catwoman soulstealer dc icons 3  7664.438356
# 1503             untitled a court of thorns and roses 4  5805.469697
# 2288             untitled a court of thorns and roses 5  5498.739726
# 2680      a reaper at the gates an ember in the ashes 3  4994.911290
# 638                          untitled throne of glass 7  3844.807563
# 2576                   chain of thorns the last hours 3  3599.221622
# 2883                                            options  3555.844156
# 1989                     chain of gold the last hours 1  3456.501742
# 1415  the queen of air and darkness the dark artific...  3230.001938

# %% [markdown]
# **Popular recommendations.**

# %% [markdown]
# **The below output is given by how likely you will enjoy the book (score) based on your liked books.**

# %% [markdown]
# **Star ratings are based on rating.**

# %%
popular_recs = all_recs[all_recs["book_count"] > 1000].sort_values("score", ascending=False)

# %%
def add_star_rating(val):
    if pd.isna(val):
        return ""
    rating = int(val)
    stars = "&#11088;" * rating
    return stars

recs["rating"] = recs["rating"].astype(float)
recs["star_rating"] = recs["rating"].apply(lambda x: add_star_rating(5) if x >= 4 else add_star_rating(x))

# Aggregate ratings for each book_id
grouped_ratings = recs.groupby("book_id")["rating"].mean().reset_index()

# Filter out books with a rating under 1
grouped_ratings = grouped_ratings[grouped_ratings["rating"] >= 1]

# Merge popular_recs and grouped_ratings DataFrames
popular_recs_with_stars = popular_recs.merge(grouped_ratings, how="left", on="book_id")

# Add estimate book rating column as star rating
popular_recs_with_stars["star_book_rating"] = popular_recs_with_stars["rating"].apply(add_star_rating)

# Filter out books with a rating under 1
popular_recs_filtered = popular_recs_with_stars[popular_recs_with_stars["rating"] >= 1]

# Formatting function for clickable URLs
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

# Formatting function for displaying cover images
def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

# Apply formatting functions and display the DataFrame
popular_recs_formatted = popular_recs_filtered[~popular_recs_filtered["book_id"].isin(liked_books)].head(10).copy()
popular_recs_formatted = popular_recs_formatted.style.format(
    {'url': make_clickable, 'cover_image': show_image}
)

# Display the DataFrame with the added columns
popular_recs_formatted = popular_recs_formatted.set_table_styles([{
    'selector': 'td.col_star_rating',
    'props': [('text-align', 'center')]
}])

popular_recs_formatted
# Out:
# <style type="text/css">
# #T_fcf3b td.col_star_rating {
#   text-align: center;
# }
# </style>
# <table id="T_fcf3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcf3b_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_fcf3b_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_fcf3b_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_fcf3b_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_fcf3b_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_fcf3b_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_fcf3b_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_fcf3b_level0_col7" class="col_heading level0 col7" >score</th>
#       <th id="T_fcf3b_level0_col8" class="col_heading level0 col8" >rating</th>
#       <th id="T_fcf3b_level0_col9" class="col_heading level0 col9" >star_book_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcf3b_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_fcf3b_row0_col0" class="data row0 col0" >25111004</td>
#       <td id="T_fcf3b_row0_col1" class="data row0 col1" >10465</td>
#       <td id="T_fcf3b_row0_col2" class="data row0 col2" >November 9</td>
#       <td id="T_fcf3b_row0_col3" class="data row0 col3" >56228</td>
#       <td id="T_fcf3b_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/25111004-november-9">Goodreads</a></td>
#       <td id="T_fcf3b_row0_col5" class="data row0 col5" ><a href="https://images.gr-assets.com/books/1447138036m/25111004.jpg"><img src="https://images.gr-assets.com/books/1447138036m/25111004.jpg" width=50></img></a></td>
#       <td id="T_fcf3b_row0_col6" class="data row0 col6" >november 9</td>
#       <td id="T_fcf3b_row0_col7" class="data row0 col7" >1947.716885</td>
#       <td id="T_fcf3b_row0_col8" class="data row0 col8" >3.041949</td>
#       <td id="T_fcf3b_row0_col9" class="data row0 col9" >&#11088;&#11088;&#11088;</td>
#     </tr>
#     <tr>
#       <th id="T_fcf3b_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_fcf3b_row1_col0" class="data row1 col0" >22609310</td>
#       <td id="T_fcf3b_row1_col1" class="data row1 col1" >11392</td>
#       <td id="T_fcf3b_row1_col2" class="data row1 col2" >Confess</td>
#       <td id="T_fcf3b_row1_col3" class="data row1 col3" >73455</td>
#       <td id="T_fcf3b_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/22609310-confess">Goodreads</a></td>
#       <td id="T_fcf3b_row1_col5" class="data row1 col5" ><a href="https://images.gr-assets.com/books/1412280173m/22609310.jpg"><img src="https://images.gr-assets.com/books/1412280173m/22609310.jpg" width=50></img></a></td>
#       <td id="T_fcf3b_row1_col6" class="data row1 col6" >confess</td>
#       <td id="T_fcf3b_row1_col7" class="data row1 col7" >1766.764196</td>
#       <td id="T_fcf3b_row1_col8" class="data row1 col8" >3.065923</td>
#       <td id="T_fcf3b_row1_col9" class="data row1 col9" >&#11088;&#11088;&#11088;</td>
#     </tr>
#     <tr>
#       <th id="T_fcf3b_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_fcf3b_row2_col0" class="data row2 col0" >24378015</td>
#       <td id="T_fcf3b_row2_col1" class="data row2 col1" >9483</td>
#       <td id="T_fcf3b_row2_col2" class="data row2 col2" >Never Never (Never Never, #1)</td>
#       <td id="T_fcf3b_row2_col3" class="data row2 col3" >56002</td>
#       <td id="T_fcf3b_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/24378015-never-never">Goodreads</a></td>
#       <td id="T_fcf3b_row2_col5" class="data row2 col5" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_fcf3b_row2_col6" class="data row2 col6" >never never never never 1</td>
#       <td id="T_fcf3b_row2_col7" class="data row2 col7" >1605.787097</td>
#       <td id="T_fcf3b_row2_col8" class="data row2 col8" >2.535274</td>
#       <td id="T_fcf3b_row2_col9" class="data row2 col9" >&#11088;&#11088;</td>
#     </tr>
#     <tr>
#       <th id="T_fcf3b_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_fcf3b_row3_col0" class="data row3 col0" >33280872</td>
#       <td id="T_fcf3b_row3_col1" class="data row3 col1" >4605</td>
#       <td id="T_fcf3b_row3_col2" class="data row3 col2" >Without Merit</td>
#       <td id="T_fcf3b_row3_col3" class="data row3 col3" >13852</td>
#       <td id="T_fcf3b_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33280872-without-merit">Goodreads</a></td>
#       <td id="T_fcf3b_row3_col5" class="data row3 col5" ><a href="https://images.gr-assets.com/books/1506608833m/33280872.jpg"><img src="https://images.gr-assets.com/books/1506608833m/33280872.jpg" width=50></img></a></td>
#       <td id="T_fcf3b_row3_col6" class="data row3 col6" >without merit</td>
#       <td id="T_fcf3b_row3_col7" class="data row3 col7" >1530.899870</td>
#       <td id="T_fcf3b_row3_col8" class="data row3 col8" >1.351792</td>
#       <td id="T_fcf3b_row3_col9" class="data row3 col9" >&#11088;</td>
#     </tr>
#     <tr>
#       <th id="T_fcf3b_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_fcf3b_row4_col0" class="data row4 col0" >29610595</td>
#       <td id="T_fcf3b_row4_col1" class="data row4 col1" >4521</td>
#       <td id="T_fcf3b_row4_col2" class="data row4 col2" >Too Late</td>
#       <td id="T_fcf3b_row4_col3" class="data row4 col3" >16204</td>
#       <td id="T_fcf3b_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/29610595-too-late">Goodreads</a></td>
#       <td id="T_fcf3b_row4_col5" class="data row4 col5" ><a href="https://images.gr-assets.com/books/1459520906m/29610595.jpg"><img src="https://images.gr-assets.com/books/1459520906m/29610595.jpg" width=50></img></a></td>
#       <td id="T_fcf3b_row4_col6" class="data row4 col6" >too late</td>
#       <td id="T_fcf3b_row4_col7" class="data row4 col7" >1261.382436</td>
#       <td id="T_fcf3b_row4_col8" class="data row4 col8" >2.252820</td>
#       <td id="T_fcf3b_row4_col9" class="data row4 col9" >&#11088;&#11088;</td>
#     </tr>
#     <tr>
#       <th id="T_fcf3b_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_fcf3b_row5_col0" class="data row5 col0" >23587984</td>
#       <td id="T_fcf3b_row5_col1" class="data row5 col1" >5652</td>
#       <td id="T_fcf3b_row5_col2" class="data row5 col2" >Maybe Not (Maybe, #1.5)</td>
#       <td id="T_fcf3b_row5_col3" class="data row5 col3" >26935</td>
#       <td id="T_fcf3b_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/23587984-maybe-not">Goodreads</a></td>
#       <td id="T_fcf3b_row5_col5" class="data row5 col5" ><a href="https://images.gr-assets.com/books/1416381591m/23587984.jpg"><img src="https://images.gr-assets.com/books/1416381591m/23587984.jpg" width=50></img></a></td>
#       <td id="T_fcf3b_row5_col6" class="data row5 col6" >maybe not maybe 15</td>
#       <td id="T_fcf3b_row5_col7" class="data row5 col7" >1186.007203</td>
#       <td id="T_fcf3b_row5_col8" class="data row5 col8" >2.760439</td>
#       <td id="T_fcf3b_row5_col9" class="data row5 col9" >&#11088;&#11088;</td>
#     </tr>
#     <tr>
#       <th id="T_fcf3b_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_fcf3b_row6_col0" class="data row6 col0" >24422492</td>
#       <td id="T_fcf3b_row6_col1" class="data row6 col1" >6136</td>
#       <td id="T_fcf3b_row6_col2" class="data row6 col2" >Never Never: Part Two (Never Never, #2)</td>
#       <td id="T_fcf3b_row6_col3" class="data row6 col3" >32240</td>
#       <td id="T_fcf3b_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/24422492-never-never">Goodreads</a></td>
